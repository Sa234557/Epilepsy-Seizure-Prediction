# %%
import os
import numpy as np
import mne  # Ensure you have MNE installed
from sklearn.metrics import classification_report

def parse_seizure_times_from_file(summary_file_path):
    seizure_times = []
    with open(summary_file_path, 'r') as file:
        lines = file.readlines()
        start_time = None
        for line in lines:
            if 'Seizure Start Time:' in line:
                start_time = int(line.split(':')[1].strip().split()[0])
            elif 'Seizure End Time:' in line and start_time is not None:
                end_time = int(line.split(':')[1].strip().split()[0])
                seizure_times.append((start_time, end_time))
                start_time = None
    return seizure_times

def extract_segments(edf_file_path, seizure_times, segment_duration=2, max_segments=100):
    raw = mne.io.read_raw_edf(edf_file_path, preload=True)
    data = raw.get_data()
    sfreq = raw.info['sfreq']
    segment_samples = int(segment_duration * sfreq)
    
    preictal_segments = []
    interictal_segments = []

    # Extract preictal segments
    for start, _ in seizure_times:
        preictal_start = max(start - 1800, 0)
        preictal_end = start
        
        for i in range(preictal_start, preictal_end, segment_samples):
            if len(preictal_segments) >= max_segments:
                break
            if i + segment_samples <= preictal_end:
                segment = data[:, i:i + segment_samples]
                preictal_segments.append(segment)

    # Extract interictal segments
    for start, _ in seizure_times:
        interictal_start = max(start - 14400, 0)
        
        for i in range(interictal_start, start - 1800, segment_samples):
            if len(interictal_segments) >= max_segments:
                break
            if i + segment_samples <= start - 1800:
                segment = data[:, i:i + segment_samples]
                interictal_segments.append(segment)

    return preictal_segments, interictal_segments

def load_data(folder_path, seizure_times, max_segments_per_file=100):
    preictal_segments = []
    interictal_segments = []
    
    for filename in os.listdir(folder_path):
        if filename.endswith('.edf'):
            edf_file_path = os.path.join(folder_path, filename)
            preictal, interictal = extract_segments(edf_file_path, seizure_times, max_segments=max_segments_per_file)
            preictal_segments.extend(preictal)
            interictal_segments.extend(interictal)

    return preictal_segments, interictal_segments

# Define paths
summary_file_path = "D:/chb-mit-scalp-eeg-database-1.0.0/chb02/chb02-summary.txt"
folder_path = "D:/chb-mit-scalp-eeg-database-1.0.0/chb02"

# Load seizure times from the summary file
seizure_times = parse_seizure_times_from_file(summary_file_path)

# Load data
preictal_segments, interictal_segments = load_data(folder_path, seizure_times)

# Count the segments
num_preictal = len(preictal_segments)
num_interictal = len(interictal_segments)

# Print the counts
print(f"Number of preictal segments: {num_preictal}")
print(f"Number of interictal segments: {num_interictal}")

# Optionally, ensure they have the same number of segments
if num_preictal != num_interictal:
    print("Warning: The number of preictal and interictal segments are not equal.")
# Out:
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_15.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_16+.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_16.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 245503  =      0.000 ...   958.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_17.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_18.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_19.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_20.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_21.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_22.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_23.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_24.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_25.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_26.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_27.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_28.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_29.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_30.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_31.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_32.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_33.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_34.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb02\chb02_35.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\1099899791.py:21: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Number of preictal segments: 216
# Number of interictal segments: 180
# Warning: The number of preictal and interictal segments are not equal.

# %%
import glob
import os.path
import numpy as np
from src.data.extractFeture import preprocess_and_extract_features_mne_with_timestamps
from src.data.extractTarget import extractTarget

def extract_data_and_labels(edf_file_path, summary_file_path):

   
    X = preprocess_and_extract_features_mne_with_timestamps(edf_file_path)
   
    seizure_start_time, seizure_end_time = extractTarget(summary_file_path, edf_file_path)
    y = np.array([1 if seizure_start_time <= row[0] <= seizure_end_time else 0 for row in X])

  
    X = X[:,1:]
    return X,y


def load_data(subject_id,base_path):
    
    edf_file_path = sorted(glob.glob(os.path.join(base_path, "chb{:02d}/*.edf".format(subject_id))))
    summary_file_path = os.path.join(base_path, "chb{:02d}/chb{:02d}-summary.txt".format(subject_id, subject_id))
    all_X = []
    all_y = []
    for edf_file_path in edf_file_path:
        X, y = extract_data_and_labels(edf_file_path, summary_file_path)
        all_X.append(X)
        all_y.append(y)
    return all_X,all_y
    import os
def extractTarget(summary_file_path, edf_file_path):
    edf_file_name = os.path.basename(edf_file_path)
    
    seizure_start_time = None
    seizure_end_time = None
   
    with open(summary_file_path, 'r') as file:
        lines = file.readlines()
   
    found = False
    
    for line in lines:
        if "File Name: " + edf_file_name in line:
            found = True
        if found:
            if "Number of Seizures in File: 0" in line:
                return None, None  
            if "Seizure Start Time:" in line:
                seizure_start_time = int(line.split(": ")[1].split(" ")[0])
            if "Seizure End Time:" in line:
                seizure_end_time = int(line.split(": ")[1].split(" ")[0])
                break  
    return seizure_start_time, seizure_end_time
    import pyedflib
import numpy as np
import tqdm
import mne
from scipy.signal import welch,stft
from scipy.stats import skew, kurtosis
from scipy.spatial.distance import euclidean

def extract_basic_features(signal):
    signal = (signal - np.mean(signal)) / np.std(signal)
    mean = np.mean(signal)
    std = np.std(signal)
    sample_entropy = np.log(np.std(np.diff(signal)))
    fuzzy_entropy = -np.log(euclidean(signal[:-1], signal[1:]) / len(signal))
    skewness = skew(signal)
    kurt = kurtosis(signal)
    return [mean, std, sample_entropy, fuzzy_entropy, skewness, kurt]

def extract_advanced_features(data, fs, window_length_sec=3):
    """
    
    """

    
    f, t, Zxx = stft(data, fs, nperseg=window_length_sec*fs)
    
    
    power = np.mean(np.abs(Zxx)**2, axis=1)  

    return power

def preprocess_and_extract_features_mne_with_timestamps(file_name):
    """
    
    """

    
    raw = mne.io.read_raw_edf(file_name, preload=True)

   
    raw.filter(1., 50., fir_design='firwin')

    
    raw.pick_types(meg=False, eeg=True, eog=False)

    
    window_length = 3  
    sfreq = raw.info['sfreq']  
    window_samples = int(window_length * sfreq)

    
    features_with_timestamps = []

   
    for start in range(0, len(raw.times), window_samples):
        end = start + window_samples
        if end > len(raw.times):
            break

        
        window_data, times = raw[:, start:end]
        window_data = np.squeeze(window_data)

        
        timestamp = raw.times[start]

        
        for channel_data in window_data:
            basic_features = extract_basic_features(channel_data)
            advanced_features = extract_advanced_features(channel_data, sfreq)
            combined_features = np.concatenate([[timestamp], basic_features, advanced_features])
            features_with_timestamps.append(combined_features)

    return np.array(features_with_timestamps)

preprocess_and_extract_features_mne_with_timestamps("data/chb01/chb01_03.edf")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       2 import os.path
#       3 import numpy as np
# ----> 4 from src.data.extractFeture import preprocess_and_extract_features_mne_with_timestamps
#       5 from src.data.extractTarget import extractTarget
#       7 def extract_data_and_labels(edf_file_path, summary_file_path):
#
# ModuleNotFoundError: No module named 'src'

# %%
import os
import glob
import numpy as np
import mne
from scipy.signal import stft
from scipy.stats import skew, kurtosis
from scipy.spatial.distance import euclidean

def extract_data_and_labels(edf_file_path, summary_file_path):
    # Preprocess the EEG data and extract features
    X = preprocess_and_extract_features_mne_with_timestamps(edf_file_path)
    
    # Extract seizure start and end times
    seizure_start_time, seizure_end_time = extract_target(summary_file_path, edf_file_path)
    
    # Create labels based on seizure times
    y = np.array([1 if seizure_start_time <= row[0] <= seizure_end_time else 0 for row in X])

    # Remove the timestamp from the feature set
    X = X[:, 1:]
    return X, y

def load_data(subject_id, base_path):
    # Generate paths for EDF files and summary files
    edf_file_paths = sorted(glob.glob(os.path.join(base_path, f"chb{subject_id:02d}/*.edf")))
    summary_file_path = os.path.join(base_path, f"chb{subject_id:02d}/chb{subject_id:02d}-summary.txt")

    all_X = []
    all_y = []
    
    for edf_file_path in edf_file_paths:
        X, y = extract_data_and_labels(edf_file_path, summary_file_path)
        all_X.append(X)
        all_y.append(y)
        
    return all_X, all_y

def extract_target(summary_file_path, edf_file_path):
    edf_file_name = os.path.basename(edf_file_path)
    
    seizure_start_time = None
    seizure_end_time = None
    
    with open(summary_file_path, 'r') as file:
        lines = file.readlines()
    
    found = False
    
    for line in lines:
        if "File Name: " + edf_file_name in line:
            found = True
        if found:
            if "Number of Seizures in File: 0" in line:
                return None, None  
            if "Seizure Start Time:" in line:
                seizure_start_time = int(line.split(": ")[1].split(" ")[0])
            if "Seizure End Time:" in line:
                seizure_end_time = int(line.split(": ")[1].split(" ")[0])
                break  
    return seizure_start_time, seizure_end_time

def extract_basic_features(signal):
    signal = (signal - np.mean(signal)) / np.std(signal)
    mean = np.mean(signal)
    std = np.std(signal)
    sample_entropy = np.log(np.std(np.diff(signal))) if len(signal) > 1 else 0
    fuzzy_entropy = -np.log(euclidean(signal[:-1], signal[1:]) / len(signal)) if len(signal) > 1 else 0
    skewness = skew(signal)
    kurt = kurtosis(signal)
    
    return [mean, std, sample_entropy, fuzzy_entropy, skewness, kurt]

def extract_advanced_features(data, fs, window_length_sec=3):
    f, t, Zxx = stft(data, fs, nperseg=window_length_sec * fs)
    power = np.mean(np.abs(Zxx)**2, axis=1)  
    return power

def preprocess_and_extract_features_mne_with_timestamps(file_name):
    raw = mne.io.read_raw_edf(file_name, preload=True)
    raw.filter(1., 50., fir_design='firwin')
    raw.pick_types(meg=False, eeg=True, eog=False)

    window_length = 3  
    sfreq = raw.info['sfreq']  
    window_samples = int(window_length * sfreq)

    features_with_timestamps = []

    for start in range(0, len(raw.times), window_samples):
        end = start + window_samples
        if end > len(raw.times):
            break

        window_data, times = raw[:, start:end]
        window_data = np.squeeze(window_data)
        timestamp = raw.times[start]

        for channel_data in window_data:
            basic_features = extract_basic_features(channel_data)
            advanced_features = extract_advanced_features(channel_data, sfreq)
            combined_features = np.concatenate([[timestamp], basic_features, advanced_features])
            features_with_timestamps.append(combined_features)

    return np.array(features_with_timestamps)

# Example of how to use the function
if __name__ == "__main__":
    base_path = ""  # Adjust this path to your data folder
    subject_id = 1  # Example subject ID
    all_X, all_y = load_data(subject_id, base_path)
    
    # Example usage of the preprocess function
    sample_file = "data/chb01/chb01_03.edf"  # Example EDF file path
    features = preprocess_and_extract_features_mne_with_timestamps(sample_file)
    print(features)

# %%
import os
import glob
import numpy as np
import mne
from scipy.signal import stft
from scipy.stats import skew, kurtosis
from scipy.spatial.distance import euclidean

def extract_data_and_labels(edf_file_path, summary_file_path):
    # Preprocess the EEG data and extract features
    X = preprocess_and_extract_features_mne_with_timestamps(edf_file_path)
    
    # Extract seizure start and end times
    seizure_start_time, seizure_end_time = extract_target(summary_file_path, edf_file_path)

    # Check if seizure times are valid
    if seizure_start_time is None or seizure_end_time is None:
        print(f"No seizure data found for {edf_file_path}.")
        return X, np.array([])  # Return empty labels if no seizure times are found

    # Create labels based on seizure times
    y = np.array([1 if seizure_start_time <= row[0] <= seizure_end_time else 0 for row in X])

    # Remove the timestamp from the feature set
    X = X[:, 1:]
    return X, y


def extract_target(summary_file_path, edf_file_path):
    edf_file_name = os.path.basename(edf_file_path)
    
    seizure_start_time = None
    seizure_end_time = None
    
    with open(summary_file_path, 'r') as file:
        lines = file.readlines()
    
    found = False
    
    for line in lines:
        if "File Name: " + edf_file_name in line:
            found = True
        if found:
            if "Number of Seizures in File: 0" in line:
                return None, None  
            if "Seizure Start Time:" in line:
                seizure_start_time = int(line.split(": ")[1].split(" ")[0])
            if "Seizure End Time:" in line:
                seizure_end_time = int(line.split(": ")[1].split(" ")[0])
                break  
    return seizure_start_time, seizure_end_time

def extract_basic_features(signal):
    signal = (signal - np.mean(signal)) / np.std(signal)
    mean = np.mean(signal)
    std = np.std(signal)
    sample_entropy = np.log(np.std(np.diff(signal))) if len(signal) > 1 else 0
    fuzzy_entropy = -np.log(euclidean(signal[:-1], signal[1:]) / len(signal)) if len(signal) > 1 else 0
    skewness = skew(signal)
    kurt = kurtosis(signal)
    
    return [mean, std, sample_entropy, fuzzy_entropy, skewness, kurt]

def extract_advanced_features(data, fs, window_length_sec=3):
    f, t, Zxx = stft(data, fs, nperseg=window_length_sec * fs)
    power = np.mean(np.abs(Zxx)**2, axis=1)  
    return power

def preprocess_and_extract_features_mne_with_timestamps(file_name):
    raw = mne.io.read_raw_edf(file_name, preload=True)
    raw.filter(1., 50., fir_design='firwin')
    raw.pick_types(meg=False, eeg=True, eog=False)

    window_length = 3  
    sfreq = raw.info['sfreq']  
    window_samples = int(window_length * sfreq)

    features_with_timestamps = []

    for start in range(0, len(raw.times), window_samples):
        end = start + window_samples
        if end > len(raw.times):
            break

        window_data, times = raw[:, start:end]
        window_data = np.squeeze(window_data)
        timestamp = raw.times[start]

        for channel_data in window_data:
            basic_features = extract_basic_features(channel_data)
            advanced_features = extract_advanced_features(channel_data, sfreq)
            combined_features = np.concatenate([[timestamp], basic_features, advanced_features])
            features_with_timestamps.append(combined_features)

    return np.array(features_with_timestamps)

def load_chb01_data(base_path):
    # Path for chb01 EDF files and summary file
    edf_file_paths = sorted(glob.glob(os.path.join(base_path, "chb01/*.edf")))
    summary_file_path = os.path.join(base_path, "chb01/chb01-summary.txt")

    all_X = []
    all_y = []
    
    for edf_file_path in edf_file_paths:
        X, y = extract_data_and_labels(edf_file_path, summary_file_path)
        all_X.append(X)  # Collect features from all files
        all_y.append(y)  # Collect labels from all files
        
    return all_X, all_y

# Example of how to use the function
if __name__ == "__main__":
    base_path = "D:/chb-mit-scalp-eeg-database-1.0.0"  # Adjust this path to your data folder
    all_X, all_y = load_chb01_data(base_path)
    
    # Check the number of files processed and their shapes
    print(f"Processed {len(all_X)} files.")
    for i, X in enumerate(all_X):
        print(f"File {i + 1}: Feature shape: {X.shape}, Label shape: {all_y[i].shape}")
# Out:
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.5s finished
# No seizure data found for D:/chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_01.edf.
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.7s finished
# No seizure data found for D:/chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_02.edf.
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.7s finished
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.5s finished
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.8s finished
# No seizure data found for D:/chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_05.edf.
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.8s finished
# No seizure data found for D:/chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_06.edf.
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.7s finished
# No seizure data found for D:/chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_07.edf.
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    2.0s finished
# No seizure data found for D:/chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_08.edf.
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.4s finished
# No seizure data found for D:/chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_09.edf.
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_13328\3718194686.py:70: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(file_name, preload=True)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[8], line 115
#     113 if __name__ == "__main__":
#     114     base_path = "D:/chb-mit-scalp-eeg-database-1.0.0"  # Adjust this path to your data folder
# --> 115     all_X, all_y = load_chb01_data(base_path)
#     117     # Check the number of files processed and their shapes
#     118     print(f"Processed {len(all_X)} files.")
#
# Cell In[8], line 106, in load_chb01_data(base_path)
#     103 all_y = []
#     105 for edf_file_path in edf_file_paths:
# --> 106     X, y = extract_data_and_labels(edf_file_path, summary_file_path)
#     107     all_X.append(X)  # Collect features from all files
#     108     all_y.append(y)  # Collect labels from all files
#
# Cell In[8], line 11, in extract_data_and_labels(edf_file_path, summary_file_path)
#       9 def extract_data_and_labels(edf_file_path, summary_file_path):
#      10     # Preprocess the EEG data and extract features
# ---> 11     X = preprocess_and_extract_features_mne_with_timestamps(edf_file_path)
#      13     # Extract seizure start and end times
#      14     seizure_start_time, seizure_end_time = extract_target(summary_file_path, edf_file_path)
#
# Cell In[8], line 70, in preprocess_and_extract_features_mne_with_timestamps(file_name)
#      69 def preprocess_and_extract_features_mne_with_timestamps(file_name):
# ---> 70     raw = mne.io.read_raw_edf(file_name, preload=True)
#      71     raw.filter(1., 50., fir_design='firwin')
#      72     raw.pick_types(meg=False, eeg=True, eog=False)
#
# File ~\anaconda3\Lib\site-packages\mne\io\edf\edf.py:1689, in read_raw_edf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, exclude_after_unique, verbose)
#    1687 if ext != "edf":
#    1688     raise NotImplementedError(f"Only EDF files are supported, got {ext}.")
# -> 1689 return RawEDF(
#    1690     input_fname=input_fname,
#    1691     eog=eog,
#    1692     misc=misc,
#    1693     stim_channel=stim_channel,
#    1694     exclude=exclude,
#    1695     infer_types=infer_types,
#    1696     preload=preload,
#    1697     include=include,
#    1698     units=units,
#    1699     encoding=encoding,
#    1700     exclude_after_unique=exclude_after_unique,
#    1701     verbose=verbose,
#    1702 )
#
# File <decorator-gen-203>:12, in __init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, exclude_after_unique, verbose)
#
# File ~\anaconda3\Lib\site-packages\mne\io\edf\edf.py:187, in RawEDF.__init__(self, input_fname, eog, misc, stim_channel, exclude, infer_types, preload, include, units, encoding, exclude_after_unique, verbose)
#     185 # Raw attributes
#     186 last_samps = [edf_info["nsamples"] - 1]
# --> 187 super().__init__(
#     188     info,
#     189     preload,
#     190     filenames=[input_fname],
#     191     raw_extras=[edf_info],
#     192     last_samps=last_samps,
#     193     orig_format="int",
#     194     orig_units=orig_units,
#     195     verbose=verbose,
#     196 )
#     198 # Read annotations from file and set it
#     199 if len(edf_info["tal_idx"]) > 0:
#     200     # Read TAL data exploiting the header info (no regexp)
#
# File <decorator-gen-185>:12, in __init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#
# File ~\anaconda3\Lib\site-packages\mne\io\base.py:301, in BaseRaw.__init__(self, info, preload, first_samps, last_samps, filenames, raw_extras, orig_format, dtype, buffer_size_sec, orig_units, verbose)
#     299 # If we have True or a string, actually do the preloading
#     300 if load_from_disk:
# --> 301     self._preload_data(preload)
#     302 self._init_kwargs = _get_argvalues()
#
# File ~\anaconda3\Lib\site-packages\mne\io\base.py:596, in BaseRaw._preload_data(self, preload)
#     591     data_buffer = None
#     592 logger.info(
#     593     "Reading %d ... %d  =  %9.3f ... %9.3f secs..."
#     594     % (0, len(self.times) - 1, 0.0, self.times[-1])
#     595 )
# --> 596 self._data = self._read_segment(data_buffer=data_buffer)
#     597 assert len(self._data) == self.info["nchan"]
#     598 self.preload = True
#
# File <decorator-gen-187>:12, in _read_segment(self, start, stop, sel, data_buffer, verbose)
#
# File ~\anaconda3\Lib\site-packages\mne\io\base.py:472, in BaseRaw._read_segment(***failed resolving arguments***)
#     470     # reindex back to original file
#     471     orig_idx = _convert_slice(self._read_picks[fi][need_idx])
# --> 472     _ReadSegmentFileProtector(self)._read_segment_file(
#     473         data[:, this_sl],
#     474         orig_idx,
#     475         fi,
#     476         int(start_file),
#     477         int(stop_file),
#     478         cals,
#     479         mult,
#     480     )
#     481     offset += n_read
#     482 return data
#
# File ~\anaconda3\Lib\site-packages\mne\io\base.py:2598, in _ReadSegmentFileProtector._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#    2597 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
# -> 2598     return self.__raw.__class__._read_segment_file(
#    2599         self, data, idx, fi, start, stop, cals, mult
#    2600     )
#
# File ~\anaconda3\Lib\site-packages\mne\io\edf\edf.py:220, in RawEDF._read_segment_file(self, data, idx, fi, start, stop, cals, mult)
#     218 def _read_segment_file(self, data, idx, fi, start, stop, cals, mult):
#     219     """Read a chunk of raw data."""
# --> 220     return _read_segment_file(
#     221         data,
#     222         idx,
#     223         fi,
#     224         start,
#     225         stop,
#     226         self._raw_extras[fi],
#     227         self._filenames[fi],
#     228         cals,
#     229         mult,
#     230     )
#
# File ~\anaconda3\Lib\site-packages\mne\io\edf\edf.py:388, in _read_segment_file(data, idx, fi, start, stop, raw_extras, filenames, cals, mult)
#     383 start_offset = data_offset + block_start_idx * ch_offsets[-1] * dtype_byte
#     385 # first read everything into the `ones` array. For channels with
#     386 # lower sampling frequency, there will be zeros left at the end of the
#     387 # row. Ignore TAL/annotations channel and only store `orig_sel`
# --> 388 ones = np.zeros((len(orig_sel), data.shape[-1]), dtype=data.dtype)
#     389 # save how many samples have already been read per channel
#     390 n_smp_read = [0 for _ in range(len(orig_sel))]
#
# MemoryError: Unable to allocate 162. MiB for an array with shape (23, 921600) and data type float64

# %%
import os
import numpy as np
import mne

# Constants
SEGMENT_DURATION = 5  # seconds per window
PREICTAL_WINDOW_DURATION = 3600  # 1 hour in seconds (preictal period before seizure)

class PreictalDataProcessor:
    def __init__(self, sampling_rate):
        self.sampling_rate = sampling_rate
        self.preictal_windows = []

    def parse_seizure_times_from_summary(self, summary_file_path):
        seizure_times = {}
        current_file = None

        with open(summary_file_path, 'r') as file:
            for line in file:
                if 'File Name:' in line:
                    current_file = line.split(':')[1].strip()
                    seizure_times[current_file] = []
                elif 'Seizure Start Time:' in line and current_file is not None:
                    start_time = int(line.split(':')[1].strip().split()[0])
                elif 'Seizure End Time:' in line and current_file is not None:
                    end_time = int(line.split(':')[1].strip().split()[0])
                    seizure_times[current_file].append((start_time, end_time))
        return seizure_times

    def segment_and_store_preictal_windows(self, edf_file_path, seizures, output_dir):
        raw = mne.io.read_raw_edf(edf_file_path, preload=True)
        data = raw.get_data()
        segment_samples = int(SEGMENT_DURATION * self.sampling_rate)
        
        for seizure_start, _ in seizures:
            preictal_start = max(seizure_start - PREICTAL_WINDOW_DURATION, 0)
            preictal_end = seizure_start

            # Segment entire file into 5-second windows and check if each window is within the preictal period
            for i in range(0, data.shape[1], segment_samples):
                window_start_time = i / self.sampling_rate
                window_end_time = (i + segment_samples) / self.sampling_rate

                if preictal_start <= window_start_time < preictal_end:
                    segment = data[:, i:i + segment_samples]
                    if segment.shape[1] == segment_samples:  # Ensure the segment is full length
                        self.preictal_windows.append(segment)

        # Save each preictal window as a .npy file
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        for idx, window in enumerate(self.preictal_windows):
            np.save(os.path.join(output_dir, f"preictal_window_{idx}.npy"), window)

    def process_folder_and_store_windows(self, edf_directory, summary_file_path, output_dir):
        seizure_times = self.parse_seizure_times_from_summary(summary_file_path)

        # Process each EDF file
        for filename in os.listdir(edf_directory):
            if filename.endswith('.edf') and filename in seizure_times:
                edf_file_path = os.path.join(edf_directory, filename)
                print(f"Processing file: {filename}")
                self.segment_and_store_preictal_windows(edf_file_path, seizure_times[filename], output_dir)

# Specify the parameters
sampling_rate = 256  # Hz (as per summary file)
edf_directory = "D:/chb-mit-scalp-eeg-database-1.0.0/chb01"  # Change as per your setup
summary_file_path = os.path.join(edf_directory, "chb01-summary.txt")
output_directory = "D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows"

# Create an instance of PreictalDataProcessor and process the data
processor = PreictalDataProcessor(sampling_rate)
processor.process_folder_and_store_windows(edf_directory, summary_file_path, output_directory)
# Out:
# Processing file: chb01_01.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# Processing file: chb01_02.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_03.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_04.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_05.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_06.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_07.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_08.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_09.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_10.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_11.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_12.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_13.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_14.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_15.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_15.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_16.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_16.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_17.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_17.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_18.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_18.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_19.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_19.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_20.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_20.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 681727  =      0.000 ...  2662.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_21.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_21.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_22.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_22.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_23.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_23.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_24.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_24.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_25.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_25.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_26.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_26.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 595199  =      0.000 ...  2324.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_27.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_27.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 153599  =      0.000 ...   599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_29.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_29.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_30.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_30.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_31.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_31.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_32.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_32.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_33.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_33.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_34.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_34.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_36.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_36.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_37.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_37.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_38.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_38.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_39.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_39.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_40.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_40.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_41.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_41.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_42.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_42.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_43.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_43.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_46.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_46.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\198671272.py:31: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)

# %%
import os
import numpy as np
import mne

# Constants for segmentation
SEGMENT_DURATION = 5  # seconds per window
PREICTAL_WINDOW_DURATION = 3600  # 1 hour in seconds (preictal period before seizure)

class PreictalDataProcessor:
    def __init__(self, sampling_rate):
        self.sampling_rate = sampling_rate
        self.preictal_windows = []
        self.total_windows_count = 0  # Counter for all windows across files

    def parse_seizure_times_from_summary(self, summary_file_path):
        seizure_times = {}
        current_file = None

        with open(summary_file_path, 'r') as file:
            for line in file:
                if 'File Name:' in line:
                    current_file = line.split(':')[1].strip()
                    seizure_times[current_file] = []
                elif 'Seizure Start Time:' in line and current_file is not None:
                    start_time = int(line.split(':')[1].strip().split()[0])
                elif 'Seizure End Time:' in line and current_file is not None:
                    end_time = int(line.split(':')[1].strip().split()[0])
                    seizure_times[current_file].append((start_time, end_time))
        print(f"Parsed seizure times from summary: {seizure_times}")
        return seizure_times

    def segment_and_store_preictal_windows(self, edf_file_path, seizures, output_dir):
        raw = mne.io.read_raw_edf(edf_file_path, preload=True)
        data = raw.get_data()
        segment_samples = int(SEGMENT_DURATION * self.sampling_rate)

        # Process each seizure and track window count
        for seizure_idx, (seizure_start, _) in enumerate(seizures, start=1):
            preictal_start = max(seizure_start - PREICTAL_WINDOW_DURATION, 0)
            preictal_end = seizure_start
            windows_count_per_seizure = 0

            print(f"\nProcessing seizure {seizure_idx} in {os.path.basename(edf_file_path)}:")
            print(f"Expected windows (full hour): {PREICTAL_WINDOW_DURATION // SEGMENT_DURATION}")
            print(f"Preictal period start: {preictal_start}s, end: {preictal_end}s.")

            # Segment entire file into 5-second windows and check if each window is within the preictal period
            for i in range(0, data.shape[1], segment_samples):
                window_start_time = i / self.sampling_rate
                window_end_time = (i + segment_samples) / self.sampling_rate

                if preictal_start <= window_start_time < preictal_end:
                    segment = data[:, i:i + segment_samples]
                    if segment.shape[1] == segment_samples:  # Ensure the segment is full length
                        self.preictal_windows.append(segment)
                        windows_count_per_seizure += 1
            
            print(f"Actual windows stored for seizure {seizure_idx}: {windows_count_per_seizure}")
            self.total_windows_count += windows_count_per_seizure

        print(f"Total preictal windows for {os.path.basename(edf_file_path)}: {self.total_windows_count}")

    def process_folder_and_store_windows(self, edf_directory, summary_file, output_dir):
        seizure_times = self.parse_seizure_times_from_summary(summary_file)

        # Process each EDF file
        for filename in os.listdir(edf_directory):
            if filename.endswith('.edf') and filename in seizure_times:
                edf_file_path = os.path.join(edf_directory, filename)
                print(f"\nProcessing file: {filename}")
                self.segment_and_store_preictal_windows(edf_file_path, seizure_times[filename], output_dir)

        print(f"\nFinal total preictal windows across all files: {self.total_windows_count}")

    def save_preictal_windows(self, output_dir):
        """
        Save each preictal segment as a .npy file in the specified output directory.
        """
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        for idx, window in enumerate(self.preictal_windows):
            output_path = os.path.join(output_dir, f"preictal_window_{idx}.npy")
            np.save(output_path, window)
            print(f"Saved window {idx} to {output_path}")

# Specify the EDF directory and summary file path
edf_directory = "D:/chb-mit-scalp-eeg-database-1.0.0/chb01"
summary_file_path = os.path.join(edf_directory, "chb01-summary.txt")
output_directory = "D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows"

# Create an instance of PreictalDataProcessor
processor = PreictalDataProcessor(sampling_rate=256)

# Process folder and store preictal windows
processor.process_folder_and_store_windows(edf_directory, summary_file_path, output_directory)

# Save all preictal windows to the output directory
processor.save_preictal_windows(output_directory)
# Out:
# Parsed seizure times from summary: {'chb01_01.edf': [], 'chb01_02.edf': [], 'chb01_03.edf': [(2996, 3036)], 'chb01_04.edf': [(1467, 1494)], 'chb01_05.edf': [], 'chb01_06.edf': [], 'chb01_07.edf': [], 'chb01_08.edf': [], 'chb01_09.edf': [], 'chb01_10.edf': [], 'chb01_11.edf': [], 'chb01_12.edf': [], 'chb01_13.edf': [], 'chb01_14.edf': [], 'chb01_15.edf': [(1732, 1772)], 'chb01_16.edf': [(1015, 1066)], 'chb01_17.edf': [], 'chb01_18.edf': [(1720, 1810)], 'chb01_19.edf': [], 'chb01_20.edf': [], 'chb01_21.edf': [(327, 420)], 'chb01_22.edf': [], 'chb01_23.edf': [], 'chb01_24.edf': [], 'chb01_25.edf': [], 'chb01_26.edf': [(1862, 1963)], 'chb01_27.edf': [], 'chb01_29.edf': [], 'chb01_30.edf': [], 'chb01_31.edf': [], 'chb01_32.edf': [], 'chb01_33.edf': [], 'chb01_34.edf': [], 'chb01_36.edf': [], 'chb01_37.edf': [], 'chb01_38.edf': [], 'chb01_39.edf': [], 'chb01_40.edf': [], 'chb01_41.edf': [], 'chb01_42.edf': [], 'chb01_43.edf': [], 'chb01_46.edf': []}
#
# Processing file: chb01_01.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_01.edf: 0
#
# Processing file: chb01_02.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_02.edf: 0
#
# Processing file: chb01_03.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing seizure 1 in chb01_03.edf:
# Expected windows (full hour): 720
# Preictal period start: 0s, end: 2996s.
# Actual windows stored for seizure 1: 600
# Total preictal windows for chb01_03.edf: 600
#
# Processing file: chb01_04.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing seizure 1 in chb01_04.edf:
# Expected windows (full hour): 720
# Preictal period start: 0s, end: 1467s.
# Actual windows stored for seizure 1: 294
# Total preictal windows for chb01_04.edf: 894
#
# Processing file: chb01_05.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_05.edf: 894
#
# Processing file: chb01_06.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_06.edf: 894
#
# Processing file: chb01_07.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_07.edf: 894
#
# Processing file: chb01_08.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_08.edf: 894
#
# Processing file: chb01_09.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_09.edf: 894
#
# Processing file: chb01_10.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_10.edf: 894
#
# Processing file: chb01_11.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_11.edf: 894
#
# Processing file: chb01_12.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_12.edf: 894
#
# Processing file: chb01_13.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_13.edf: 894
#
# Processing file: chb01_14.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_14.edf: 894
#
# Processing file: chb01_15.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_15.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing seizure 1 in chb01_15.edf:
# Expected windows (full hour): 720
# Preictal period start: 0s, end: 1732s.
# Actual windows stored for seizure 1: 347
# Total preictal windows for chb01_15.edf: 1241
#
# Processing file: chb01_16.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_16.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing seizure 1 in chb01_16.edf:
# Expected windows (full hour): 720
# Preictal period start: 0s, end: 1015s.
# Actual windows stored for seizure 1: 203
# Total preictal windows for chb01_16.edf: 1444
#
# Processing file: chb01_17.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_17.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_17.edf: 1444
#
# Processing file: chb01_18.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_18.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing seizure 1 in chb01_18.edf:
# Expected windows (full hour): 720
# Preictal period start: 0s, end: 1720s.
# Actual windows stored for seizure 1: 344
# Total preictal windows for chb01_18.edf: 1788
#
# Processing file: chb01_19.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_19.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_19.edf: 1788
#
# Processing file: chb01_20.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_20.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 681727  =      0.000 ...  2662.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_20.edf: 1788
#
# Processing file: chb01_21.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_21.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing seizure 1 in chb01_21.edf:
# Expected windows (full hour): 720
# Preictal period start: 0s, end: 327s.
# Actual windows stored for seizure 1: 66
# Total preictal windows for chb01_21.edf: 1854
#
# Processing file: chb01_22.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_22.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_22.edf: 1854
#
# Processing file: chb01_23.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_23.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_23.edf: 1854
#
# Processing file: chb01_24.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_24.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_24.edf: 1854
#
# Processing file: chb01_25.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_25.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_25.edf: 1854
#
# Processing file: chb01_26.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_26.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 595199  =      0.000 ...  2324.996 secs...
#
# Processing seizure 1 in chb01_26.edf:
# Expected windows (full hour): 720
# Preictal period start: 0s, end: 1862s.
# Actual windows stored for seizure 1: 373
# Total preictal windows for chb01_26.edf: 2227
#
# Processing file: chb01_27.edf
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_27.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 153599  =      0.000 ...   599.996 secs...
# Total preictal windows for chb01_27.edf: 2227
#
# Processing file: chb01_29.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_29.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_29.edf: 2227
#
# Processing file: chb01_30.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_30.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_30.edf: 2227
#
# Processing file: chb01_31.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_31.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_31.edf: 2227
#
# Processing file: chb01_32.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_32.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_32.edf: 2227
#
# Processing file: chb01_33.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_33.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_33.edf: 2227
#
# Processing file: chb01_34.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_34.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_34.edf: 2227
#
# Processing file: chb01_36.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_36.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_36.edf: 2227
#
# Processing file: chb01_37.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_37.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_37.edf: 2227
#
# Processing file: chb01_38.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_38.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_38.edf: 2227
#
# Processing file: chb01_39.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_39.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_39.edf: 2227
#
# Processing file: chb01_40.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_40.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_40.edf: 2227
#
# Processing file: chb01_41.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_41.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_41.edf: 2227
#
# Processing file: chb01_42.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_42.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_42.edf: 2227
#
# Processing file: chb01_43.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_43.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_43.edf: 2227
#
# Processing file: chb01_46.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_46.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\515615846.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Total preictal windows for chb01_46.edf: 2227
#
# Final total preictal windows across all files: 2227
# Saved window 0 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_0.npy
# Saved window 1 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_1.npy
# Saved window 2 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2.npy
# Saved window 3 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_3.npy
# Saved window 4 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_4.npy
# Saved window 5 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_5.npy
# Saved window 6 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_6.npy
# Saved window 7 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_7.npy
# Saved window 8 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_8.npy
# Saved window 9 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_9.npy
# Saved window 10 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_10.npy
# Saved window 11 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_11.npy
# Saved window 12 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_12.npy
# Saved window 13 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_13.npy
# Saved window 14 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_14.npy
# Saved window 15 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_15.npy
# Saved window 16 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_16.npy
# Saved window 17 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_17.npy
# Saved window 18 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_18.npy
# Saved window 19 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_19.npy
# Saved window 20 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_20.npy
# Saved window 21 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_21.npy
# Saved window 22 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_22.npy
# Saved window 23 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_23.npy
# Saved window 24 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_24.npy
# Saved window 25 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_25.npy
# Saved window 26 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_26.npy
# Saved window 27 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_27.npy
# Saved window 28 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_28.npy
# Saved window 29 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_29.npy
# Saved window 30 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_30.npy
# Saved window 31 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_31.npy
# Saved window 32 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_32.npy
# Saved window 33 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_33.npy
# Saved window 34 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_34.npy
# Saved window 35 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_35.npy
# Saved window 36 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_36.npy
# Saved window 37 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_37.npy
# Saved window 38 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_38.npy
# Saved window 39 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_39.npy
# Saved window 40 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_40.npy
# Saved window 41 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_41.npy
# Saved window 42 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_42.npy
# Saved window 43 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_43.npy
# Saved window 44 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_44.npy
# Saved window 45 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_45.npy
# Saved window 46 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_46.npy
# Saved window 47 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_47.npy
# Saved window 48 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_48.npy
# Saved window 49 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_49.npy
# Saved window 50 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_50.npy
# Saved window 51 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_51.npy
# Saved window 52 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_52.npy
# Saved window 53 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_53.npy
# Saved window 54 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_54.npy
# Saved window 55 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_55.npy
# Saved window 56 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_56.npy
# Saved window 57 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_57.npy
# Saved window 58 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_58.npy
# Saved window 59 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_59.npy
# Saved window 60 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_60.npy
# Saved window 61 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_61.npy
# Saved window 62 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_62.npy
# Saved window 63 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_63.npy
# Saved window 64 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_64.npy
# Saved window 65 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_65.npy
# Saved window 66 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_66.npy
# Saved window 67 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_67.npy
# Saved window 68 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_68.npy
# Saved window 69 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_69.npy
# Saved window 70 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_70.npy
# Saved window 71 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_71.npy
# Saved window 72 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_72.npy
# Saved window 73 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_73.npy
# Saved window 74 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_74.npy
# Saved window 75 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_75.npy
# Saved window 76 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_76.npy
# Saved window 77 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_77.npy
# Saved window 78 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_78.npy
# Saved window 79 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_79.npy
# Saved window 80 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_80.npy
# Saved window 81 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_81.npy
# Saved window 82 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_82.npy
# Saved window 83 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_83.npy
# Saved window 84 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_84.npy
# Saved window 85 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_85.npy
# Saved window 86 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_86.npy
# Saved window 87 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_87.npy
# Saved window 88 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_88.npy
# Saved window 89 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_89.npy
# Saved window 90 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_90.npy
# Saved window 91 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_91.npy
# Saved window 92 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_92.npy
# Saved window 93 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_93.npy
# Saved window 94 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_94.npy
# Saved window 95 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_95.npy
# Saved window 96 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_96.npy
# Saved window 97 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_97.npy
# Saved window 98 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_98.npy
# Saved window 99 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_99.npy
# Saved window 100 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_100.npy
# Saved window 101 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_101.npy
# Saved window 102 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_102.npy
# Saved window 103 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_103.npy
# Saved window 104 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_104.npy
# Saved window 105 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_105.npy
# Saved window 106 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_106.npy
# Saved window 107 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_107.npy
# Saved window 108 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_108.npy
# Saved window 109 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_109.npy
# Saved window 110 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_110.npy
# Saved window 111 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_111.npy
# Saved window 112 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_112.npy
# Saved window 113 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_113.npy
# Saved window 114 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_114.npy
# Saved window 115 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_115.npy
# Saved window 116 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_116.npy
# Saved window 117 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_117.npy
# Saved window 118 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_118.npy
# Saved window 119 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_119.npy
# Saved window 120 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_120.npy
# Saved window 121 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_121.npy
# Saved window 122 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_122.npy
# Saved window 123 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_123.npy
# Saved window 124 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_124.npy
# Saved window 125 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_125.npy
# Saved window 126 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_126.npy
# Saved window 127 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_127.npy
# Saved window 128 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_128.npy
# Saved window 129 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_129.npy
# Saved window 130 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_130.npy
# Saved window 131 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_131.npy
# Saved window 132 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_132.npy
# Saved window 133 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_133.npy
# Saved window 134 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_134.npy
# Saved window 135 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_135.npy
# Saved window 136 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_136.npy
# Saved window 137 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_137.npy
# Saved window 138 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_138.npy
# Saved window 139 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_139.npy
# Saved window 140 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_140.npy
# Saved window 141 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_141.npy
# Saved window 142 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_142.npy
# Saved window 143 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_143.npy
# Saved window 144 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_144.npy
# Saved window 145 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_145.npy
# Saved window 146 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_146.npy
# Saved window 147 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_147.npy
# Saved window 148 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_148.npy
# Saved window 149 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_149.npy
# Saved window 150 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_150.npy
# Saved window 151 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_151.npy
# Saved window 152 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_152.npy
# Saved window 153 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_153.npy
# Saved window 154 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_154.npy
# Saved window 155 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_155.npy
# Saved window 156 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_156.npy
# Saved window 157 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_157.npy
# Saved window 158 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_158.npy
# Saved window 159 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_159.npy
# Saved window 160 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_160.npy
# Saved window 161 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_161.npy
# Saved window 162 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_162.npy
# Saved window 163 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_163.npy
# Saved window 164 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_164.npy
# Saved window 165 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_165.npy
# Saved window 166 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_166.npy
# Saved window 167 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_167.npy
# Saved window 168 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_168.npy
# Saved window 169 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_169.npy
# Saved window 170 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_170.npy
# Saved window 171 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_171.npy
# Saved window 172 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_172.npy
# Saved window 173 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_173.npy
# Saved window 174 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_174.npy
# Saved window 175 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_175.npy
# Saved window 176 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_176.npy
# Saved window 177 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_177.npy
# Saved window 178 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_178.npy
# Saved window 179 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_179.npy
# Saved window 180 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_180.npy
# Saved window 181 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_181.npy
# Saved window 182 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_182.npy
# Saved window 183 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_183.npy
# Saved window 184 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_184.npy
# Saved window 185 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_185.npy
# Saved window 186 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_186.npy
# Saved window 187 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_187.npy
# Saved window 188 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_188.npy
# Saved window 189 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_189.npy
# Saved window 190 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_190.npy
# Saved window 191 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_191.npy
# Saved window 192 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_192.npy
# Saved window 193 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_193.npy
# Saved window 194 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_194.npy
# Saved window 195 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_195.npy
# Saved window 196 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_196.npy
# Saved window 197 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_197.npy
# Saved window 198 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_198.npy
# Saved window 199 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_199.npy
# Saved window 200 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_200.npy
# Saved window 201 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_201.npy
# Saved window 202 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_202.npy
# Saved window 203 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_203.npy
# Saved window 204 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_204.npy
# Saved window 205 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_205.npy
# Saved window 206 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_206.npy
# Saved window 207 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_207.npy
# Saved window 208 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_208.npy
# Saved window 209 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_209.npy
# Saved window 210 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_210.npy
# Saved window 211 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_211.npy
# Saved window 212 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_212.npy
# Saved window 213 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_213.npy
# Saved window 214 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_214.npy
# Saved window 215 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_215.npy
# Saved window 216 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_216.npy
# Saved window 217 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_217.npy
# Saved window 218 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_218.npy
# Saved window 219 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_219.npy
# Saved window 220 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_220.npy
# Saved window 221 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_221.npy
# Saved window 222 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_222.npy
# Saved window 223 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_223.npy
# Saved window 224 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_224.npy
# Saved window 225 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_225.npy
# Saved window 226 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_226.npy
# Saved window 227 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_227.npy
# Saved window 228 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_228.npy
# Saved window 229 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_229.npy
# Saved window 230 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_230.npy
# Saved window 231 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_231.npy
# Saved window 232 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_232.npy
# Saved window 233 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_233.npy
# Saved window 234 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_234.npy
# Saved window 235 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_235.npy
# Saved window 236 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_236.npy
# Saved window 237 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_237.npy
# Saved window 238 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_238.npy
# ...
# Saved window 2066 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2066.npy
# Saved window 2067 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2067.npy
# Saved window 2068 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2068.npy
# Saved window 2069 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2069.npy
# Saved window 2070 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2070.npy
# Saved window 2071 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2071.npy
# Saved window 2072 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2072.npy
# Saved window 2073 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2073.npy
# Saved window 2074 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2074.npy
# Saved window 2075 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2075.npy
# Saved window 2076 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2076.npy
# Saved window 2077 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2077.npy
# Saved window 2078 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2078.npy
# Saved window 2079 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2079.npy
# Saved window 2080 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2080.npy
# Saved window 2081 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2081.npy
# Saved window 2082 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2082.npy
# Saved window 2083 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2083.npy
# Saved window 2084 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2084.npy
# Saved window 2085 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2085.npy
# Saved window 2086 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2086.npy
# Saved window 2087 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2087.npy
# Saved window 2088 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2088.npy
# Saved window 2089 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2089.npy
# Saved window 2090 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2090.npy
# Saved window 2091 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2091.npy
# Saved window 2092 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2092.npy
# Saved window 2093 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2093.npy
# Saved window 2094 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2094.npy
# Saved window 2095 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2095.npy
# Saved window 2096 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2096.npy
# Saved window 2097 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2097.npy
# Saved window 2098 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2098.npy
# Saved window 2099 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2099.npy
# Saved window 2100 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2100.npy
# Saved window 2101 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2101.npy
# Saved window 2102 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2102.npy
# Saved window 2103 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2103.npy
# Saved window 2104 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2104.npy
# Saved window 2105 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2105.npy
# Saved window 2106 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2106.npy
# Saved window 2107 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2107.npy
# Saved window 2108 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2108.npy
# Saved window 2109 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2109.npy
# Saved window 2110 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2110.npy
# Saved window 2111 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2111.npy
# Saved window 2112 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2112.npy
# Saved window 2113 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2113.npy
# Saved window 2114 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2114.npy
# Saved window 2115 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2115.npy
# Saved window 2116 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2116.npy
# Saved window 2117 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2117.npy
# Saved window 2118 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2118.npy
# Saved window 2119 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2119.npy
# Saved window 2120 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2120.npy
# Saved window 2121 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2121.npy
# Saved window 2122 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2122.npy
# Saved window 2123 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2123.npy
# Saved window 2124 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2124.npy
# Saved window 2125 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2125.npy
# Saved window 2126 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2126.npy
# Saved window 2127 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2127.npy
# Saved window 2128 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2128.npy
# Saved window 2129 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2129.npy
# Saved window 2130 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2130.npy
# Saved window 2131 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2131.npy
# Saved window 2132 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2132.npy
# Saved window 2133 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2133.npy
# Saved window 2134 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2134.npy
# Saved window 2135 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2135.npy
# Saved window 2136 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2136.npy
# Saved window 2137 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2137.npy
# Saved window 2138 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2138.npy
# Saved window 2139 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2139.npy
# Saved window 2140 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2140.npy
# Saved window 2141 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2141.npy
# Saved window 2142 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2142.npy
# Saved window 2143 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2143.npy
# Saved window 2144 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2144.npy
# Saved window 2145 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2145.npy
# Saved window 2146 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2146.npy
# Saved window 2147 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2147.npy
# Saved window 2148 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2148.npy
# Saved window 2149 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2149.npy
# Saved window 2150 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2150.npy
# Saved window 2151 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2151.npy
# Saved window 2152 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2152.npy
# Saved window 2153 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2153.npy
# Saved window 2154 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2154.npy
# Saved window 2155 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2155.npy
# Saved window 2156 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2156.npy
# Saved window 2157 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2157.npy
# Saved window 2158 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2158.npy
# Saved window 2159 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2159.npy
# Saved window 2160 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2160.npy
# Saved window 2161 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2161.npy
# Saved window 2162 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2162.npy
# Saved window 2163 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2163.npy
# Saved window 2164 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2164.npy
# Saved window 2165 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2165.npy
# Saved window 2166 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2166.npy
# Saved window 2167 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2167.npy
# Saved window 2168 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2168.npy
# Saved window 2169 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2169.npy
# Saved window 2170 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2170.npy
# Saved window 2171 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2171.npy
# Saved window 2172 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2172.npy
# Saved window 2173 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2173.npy
# Saved window 2174 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2174.npy
# Saved window 2175 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2175.npy
# Saved window 2176 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2176.npy
# Saved window 2177 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2177.npy
# Saved window 2178 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2178.npy
# Saved window 2179 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2179.npy
# Saved window 2180 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2180.npy
# Saved window 2181 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2181.npy
# Saved window 2182 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2182.npy
# Saved window 2183 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2183.npy
# Saved window 2184 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2184.npy
# Saved window 2185 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2185.npy
# Saved window 2186 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2186.npy
# Saved window 2187 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2187.npy
# Saved window 2188 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2188.npy
# Saved window 2189 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2189.npy
# Saved window 2190 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2190.npy
# Saved window 2191 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2191.npy
# Saved window 2192 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2192.npy
# Saved window 2193 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2193.npy
# Saved window 2194 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2194.npy
# Saved window 2195 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2195.npy
# Saved window 2196 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2196.npy
# Saved window 2197 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2197.npy
# Saved window 2198 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2198.npy
# Saved window 2199 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2199.npy
# Saved window 2200 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2200.npy
# Saved window 2201 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2201.npy
# Saved window 2202 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2202.npy
# Saved window 2203 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2203.npy
# Saved window 2204 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2204.npy
# Saved window 2205 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2205.npy
# Saved window 2206 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2206.npy
# Saved window 2207 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2207.npy
# Saved window 2208 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2208.npy
# Saved window 2209 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2209.npy
# Saved window 2210 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2210.npy
# Saved window 2211 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2211.npy
# Saved window 2212 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2212.npy
# Saved window 2213 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2213.npy
# Saved window 2214 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2214.npy
# Saved window 2215 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2215.npy
# Saved window 2216 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2216.npy
# Saved window 2217 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2217.npy
# Saved window 2218 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2218.npy
# Saved window 2219 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2219.npy
# Saved window 2220 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2220.npy
# Saved window 2221 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2221.npy
# Saved window 2222 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2222.npy
# Saved window 2223 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2223.npy
# Saved window 2224 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2224.npy
# Saved window 2225 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2225.npy
# Saved window 2226 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows\preictal_window_2226.npy

# %%
import os
import numpy as np
import mne
import random

# Constants for segmentation
SEGMENT_DURATION = 5  # seconds per window
PREICTAL_WINDOW_DURATION = 3600  # 1 hour in seconds
MIN_INTERICTAL_AWAY = 3600  # Minimum 1 hour away from seizures

class PreictalDataProcessor:
    def __init__(self, sampling_rate):
        self.sampling_rate = sampling_rate
        self.preictal_windows = []
        self.interictal_windows = []

    def parse_seizure_times_from_summary(self, summary_file_path):
        seizure_times = {}
        current_file = None

        with open(summary_file_path, 'r') as file:
            for line in file:
                if 'File Name:' in line:
                    current_file = line.split(':')[1].strip()
                    seizure_times[current_file] = []
                elif 'Seizure Start Time:' in line and current_file is not None:
                    start_time = int(line.split(':')[1].strip().split()[0])
                elif 'Seizure End Time:' in line and current_file is not None:
                    end_time = int(line.split(':')[1].strip().split()[0])
                    seizure_times[current_file].append((start_time, end_time))
        return seizure_times

    def segment_and_store_preictal_windows(self, edf_file_path, seizures, output_dir):
        raw = mne.io.read_raw_edf(edf_file_path, preload=True)
        data = raw.get_data()
        segment_samples = int(SEGMENT_DURATION * self.sampling_rate)

        for seizure_start, _ in seizures:
            preictal_start = max(seizure_start - PREICTAL_WINDOW_DURATION, 0)
            preictal_end = seizure_start

            # Segment the preictal period into 5-second windows
            for i in range(0, data.shape[1], segment_samples):
                window_start_time = i / self.sampling_rate
                window_end_time = (i + segment_samples) / self.sampling_rate

                if preictal_start <= window_start_time < preictal_end:
                    segment = data[:, i:i + segment_samples]
                    if segment.shape[1] == segment_samples:  # Ensure the segment is full length
                        self.preictal_windows.append(segment)

    def segment_and_store_interictal_windows(self, edf_file_path, seizures):
        raw = mne.io.read_raw_edf(edf_file_path, preload=True)
        data = raw.get_data()
        segment_samples = int(SEGMENT_DURATION * self.sampling_rate)

        interictal_start = 0  # Start of the recording
        total_time = data.shape[1] / self.sampling_rate  # Total duration of the recording in seconds

        # Iterate through all seizures to define interictal periods
        for seizure_start, seizure_end in seizures:
            # Store interictal segments before the first seizure
            if seizure_start > interictal_start:
                self.extract_interictal_windows(interictal_start, seizure_start, data)

            # Move the interictal start to the end of the current seizure
            interictal_start = seizure_end + MIN_INTERICTAL_AWAY

        # Store interictal segments after the last seizure
        if interictal_start < total_time:
            self.extract_interictal_windows(interictal_start, total_time, data)

    def extract_interictal_windows(self, start, end, data):
        segment_samples = int(SEGMENT_DURATION * self.sampling_rate)

        for i in range(int(start * self.sampling_rate), int(end * self.sampling_rate), segment_samples):
            if i + segment_samples <= end * self.sampling_rate:  # Ensure full segment
                segment = data[:, i:i + segment_samples]
                self.interictal_windows.append(segment)

    def process_folder_and_store_windows(self, edf_directory, summary_file, output_dir):
        seizure_times = self.parse_seizure_times_from_summary(summary_file)

        for filename in os.listdir(edf_directory):
            if filename.endswith('.edf') and filename in seizure_times:
                edf_file_path = os.path.join(edf_directory, filename)
                print(f"\nProcessing file: {filename}")
                self.segment_and_store_preictal_windows(edf_file_path, seizure_times[filename], output_dir)
                self.segment_and_store_interictal_windows(edf_file_path, seizure_times[filename])

        # Limit the interictal windows to match the number of preictal windows
        num_preictal_windows = len(self.preictal_windows)
        if len(self.interictal_windows) > num_preictal_windows:
            self.interictal_windows = random.sample(self.interictal_windows, num_preictal_windows)

    def save_preictal_windows(self, output_dir):
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        for idx, window in enumerate(self.preictal_windows):
            output_path = os.path.join(output_dir, f"preictal_window_{idx}.npy")
            np.save(output_path, window)
            print(f"Saved preictal window {idx} to {output_path}")

    def save_interictal_windows(self, output_dir):
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        for idx, window in enumerate(self.interictal_windows):
            output_path = os.path.join(output_dir, f"interictal_window_{idx}.npy")
            np.save(output_path, window)
            print(f"Saved interictal window {idx} to {output_path}")

# Specify the EDF directory and summary file path
edf_directory = "D:/chb-mit-scalp-eeg-database-1.0.0/chb01"
summary_file_path = os.path.join(edf_directory, "chb01-summary.txt")
output_directory = "D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1"
interictal_output_directory = "D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows"

# Create an instance of PreictalDataProcessor
processor = PreictalDataProcessor(sampling_rate=256)

# Process folder and store preictal windows
processor.process_folder_and_store_windows(edf_directory, summary_file_path, output_directory)

# Save all preictal windows to the output directory
processor.save_preictal_windows(output_directory)

# Save interictal windows to the specified output directory
processor.save_interictal_windows(interictal_output_directory)
# Out:
# Processing file: chb01_01.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_02.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_03.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_04.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_05.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_06.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_07.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_08.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_09.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_10.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_11.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_12.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_13.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_14.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_15.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_15.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_15.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_16.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_16.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_16.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_17.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_17.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_17.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_18.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_18.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_18.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_19.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_19.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_19.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_20.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_20.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 681727  =      0.000 ...  2662.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_20.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 681727  =      0.000 ...  2662.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_21.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_21.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_21.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_22.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_22.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_22.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_23.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_23.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_23.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_24.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_24.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_24.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_25.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_25.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_25.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_26.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_26.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 595199  =      0.000 ...  2324.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_26.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 595199  =      0.000 ...  2324.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_27.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_27.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 153599  =      0.000 ...   599.996 secs...
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_27.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 153599  =      0.000 ...   599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_29.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_29.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_29.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_30.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_30.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_30.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_31.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_31.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_31.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_32.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_32.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_32.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_33.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_33.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_33.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_34.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_34.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_34.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_36.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_36.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_36.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_37.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_37.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_37.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_38.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_38.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_38.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_39.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_39.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_39.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_40.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_40.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_40.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_41.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_41.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_41.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_42.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_42.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_42.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_43.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_43.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_43.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Processing file: chb01_46.edf
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_46.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:34: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Extracting EDF parameters from D:\chb-mit-scalp-eeg-database-1.0.0\chb01\chb01_46.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 921599  =      0.000 ...  3599.996 secs...
# C:\Users\HP\AppData\Local\Temp\ipykernel_42412\3482071786.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(edf_file_path, preload=True)
# Saved preictal window 0 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_0.npy
# Saved preictal window 1 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_1.npy
# Saved preictal window 2 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_2.npy
# Saved preictal window 3 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_3.npy
# Saved preictal window 4 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_4.npy
# Saved preictal window 5 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_5.npy
# Saved preictal window 6 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_6.npy
# Saved preictal window 7 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_7.npy
# Saved preictal window 8 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_8.npy
# Saved preictal window 9 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_9.npy
# Saved preictal window 10 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_10.npy
# Saved preictal window 11 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_11.npy
# Saved preictal window 12 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_12.npy
# Saved preictal window 13 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_13.npy
# Saved preictal window 14 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_14.npy
# Saved preictal window 15 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_15.npy
# Saved preictal window 16 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_16.npy
# Saved preictal window 17 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_17.npy
# Saved preictal window 18 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_18.npy
# Saved preictal window 19 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_19.npy
# Saved preictal window 20 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_20.npy
# Saved preictal window 21 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_21.npy
# Saved preictal window 22 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_22.npy
# Saved preictal window 23 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_23.npy
# Saved preictal window 24 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_24.npy
# Saved preictal window 25 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_25.npy
# Saved preictal window 26 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_26.npy
# Saved preictal window 27 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_27.npy
# Saved preictal window 28 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_28.npy
# Saved preictal window 29 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_29.npy
# Saved preictal window 30 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_30.npy
# Saved preictal window 31 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_31.npy
# Saved preictal window 32 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_32.npy
# Saved preictal window 33 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_33.npy
# Saved preictal window 34 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_34.npy
# Saved preictal window 35 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_35.npy
# Saved preictal window 36 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_36.npy
# Saved preictal window 37 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_37.npy
# Saved preictal window 38 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_38.npy
# Saved preictal window 39 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_39.npy
# Saved preictal window 40 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_40.npy
# Saved preictal window 41 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_41.npy
# Saved preictal window 42 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_42.npy
# Saved preictal window 43 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_43.npy
# Saved preictal window 44 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_44.npy
# Saved preictal window 45 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_45.npy
# Saved preictal window 46 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_46.npy
# Saved preictal window 47 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_47.npy
# Saved preictal window 48 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_48.npy
# Saved preictal window 49 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_49.npy
# Saved preictal window 50 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_50.npy
# Saved preictal window 51 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_51.npy
# Saved preictal window 52 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_52.npy
# Saved preictal window 53 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_53.npy
# Saved preictal window 54 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_54.npy
# Saved preictal window 55 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_55.npy
# Saved preictal window 56 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_56.npy
# Saved preictal window 57 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_57.npy
# Saved preictal window 58 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_58.npy
# Saved preictal window 59 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_59.npy
# Saved preictal window 60 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_60.npy
# Saved preictal window 61 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_61.npy
# Saved preictal window 62 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_62.npy
# Saved preictal window 63 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_63.npy
# Saved preictal window 64 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_64.npy
# Saved preictal window 65 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_65.npy
# Saved preictal window 66 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_66.npy
# Saved preictal window 67 to D:/chb-mit-scalp-eeg-database-1.0.0/preictal_windows1\preictal_window_67.npy
# ...
# Saved interictal window 2087 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2087.npy
# Saved interictal window 2088 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2088.npy
# Saved interictal window 2089 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2089.npy
# Saved interictal window 2090 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2090.npy
# Saved interictal window 2091 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2091.npy
# Saved interictal window 2092 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2092.npy
# Saved interictal window 2093 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2093.npy
# Saved interictal window 2094 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2094.npy
# Saved interictal window 2095 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2095.npy
# Saved interictal window 2096 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2096.npy
# Saved interictal window 2097 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2097.npy
# Saved interictal window 2098 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2098.npy
# Saved interictal window 2099 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2099.npy
# Saved interictal window 2100 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2100.npy
# Saved interictal window 2101 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2101.npy
# Saved interictal window 2102 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2102.npy
# Saved interictal window 2103 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2103.npy
# Saved interictal window 2104 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2104.npy
# Saved interictal window 2105 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2105.npy
# Saved interictal window 2106 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2106.npy
# Saved interictal window 2107 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2107.npy
# Saved interictal window 2108 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2108.npy
# Saved interictal window 2109 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2109.npy
# Saved interictal window 2110 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2110.npy
# Saved interictal window 2111 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2111.npy
# Saved interictal window 2112 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2112.npy
# Saved interictal window 2113 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2113.npy
# Saved interictal window 2114 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2114.npy
# Saved interictal window 2115 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2115.npy
# Saved interictal window 2116 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2116.npy
# Saved interictal window 2117 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2117.npy
# Saved interictal window 2118 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2118.npy
# Saved interictal window 2119 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2119.npy
# Saved interictal window 2120 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2120.npy
# Saved interictal window 2121 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2121.npy
# Saved interictal window 2122 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2122.npy
# Saved interictal window 2123 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2123.npy
# Saved interictal window 2124 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2124.npy
# Saved interictal window 2125 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2125.npy
# Saved interictal window 2126 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2126.npy
# Saved interictal window 2127 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2127.npy
# Saved interictal window 2128 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2128.npy
# Saved interictal window 2129 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2129.npy
# Saved interictal window 2130 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2130.npy
# Saved interictal window 2131 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2131.npy
# Saved interictal window 2132 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2132.npy
# Saved interictal window 2133 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2133.npy
# Saved interictal window 2134 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2134.npy
# Saved interictal window 2135 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2135.npy
# Saved interictal window 2136 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2136.npy
# Saved interictal window 2137 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2137.npy
# Saved interictal window 2138 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2138.npy
# Saved interictal window 2139 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2139.npy
# Saved interictal window 2140 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2140.npy
# Saved interictal window 2141 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2141.npy
# Saved interictal window 2142 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2142.npy
# Saved interictal window 2143 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2143.npy
# Saved interictal window 2144 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2144.npy
# Saved interictal window 2145 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2145.npy
# Saved interictal window 2146 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2146.npy
# Saved interictal window 2147 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2147.npy
# Saved interictal window 2148 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2148.npy
# Saved interictal window 2149 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2149.npy
# Saved interictal window 2150 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2150.npy
# Saved interictal window 2151 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2151.npy
# Saved interictal window 2152 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2152.npy
# Saved interictal window 2153 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2153.npy
# Saved interictal window 2154 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2154.npy
# Saved interictal window 2155 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2155.npy
# Saved interictal window 2156 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2156.npy
# Saved interictal window 2157 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2157.npy
# Saved interictal window 2158 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2158.npy
# Saved interictal window 2159 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2159.npy
# Saved interictal window 2160 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2160.npy
# Saved interictal window 2161 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2161.npy
# Saved interictal window 2162 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2162.npy
# Saved interictal window 2163 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2163.npy
# Saved interictal window 2164 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2164.npy
# Saved interictal window 2165 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2165.npy
# Saved interictal window 2166 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2166.npy
# Saved interictal window 2167 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2167.npy
# Saved interictal window 2168 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2168.npy
# Saved interictal window 2169 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2169.npy
# Saved interictal window 2170 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2170.npy
# Saved interictal window 2171 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2171.npy
# Saved interictal window 2172 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2172.npy
# Saved interictal window 2173 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2173.npy
# Saved interictal window 2174 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2174.npy
# Saved interictal window 2175 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2175.npy
# Saved interictal window 2176 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2176.npy
# Saved interictal window 2177 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2177.npy
# Saved interictal window 2178 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2178.npy
# Saved interictal window 2179 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2179.npy
# Saved interictal window 2180 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2180.npy
# Saved interictal window 2181 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2181.npy
# Saved interictal window 2182 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2182.npy
# Saved interictal window 2183 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2183.npy
# Saved interictal window 2184 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2184.npy
# Saved interictal window 2185 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2185.npy
# Saved interictal window 2186 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2186.npy
# Saved interictal window 2187 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2187.npy
# Saved interictal window 2188 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2188.npy
# Saved interictal window 2189 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2189.npy
# Saved interictal window 2190 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2190.npy
# Saved interictal window 2191 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2191.npy
# Saved interictal window 2192 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2192.npy
# Saved interictal window 2193 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2193.npy
# Saved interictal window 2194 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2194.npy
# Saved interictal window 2195 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2195.npy
# Saved interictal window 2196 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2196.npy
# Saved interictal window 2197 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2197.npy
# Saved interictal window 2198 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2198.npy
# Saved interictal window 2199 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2199.npy
# Saved interictal window 2200 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2200.npy
# Saved interictal window 2201 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2201.npy
# Saved interictal window 2202 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2202.npy
# Saved interictal window 2203 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2203.npy
# Saved interictal window 2204 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2204.npy
# Saved interictal window 2205 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2205.npy
# Saved interictal window 2206 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2206.npy
# Saved interictal window 2207 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2207.npy
# Saved interictal window 2208 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2208.npy
# Saved interictal window 2209 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2209.npy
# Saved interictal window 2210 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2210.npy
# Saved interictal window 2211 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2211.npy
# Saved interictal window 2212 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2212.npy
# Saved interictal window 2213 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2213.npy
# Saved interictal window 2214 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2214.npy
# Saved interictal window 2215 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2215.npy
# Saved interictal window 2216 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2216.npy
# Saved interictal window 2217 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2217.npy
# Saved interictal window 2218 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2218.npy
# Saved interictal window 2219 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2219.npy
# Saved interictal window 2220 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2220.npy
# Saved interictal window 2221 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2221.npy
# Saved interictal window 2222 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2222.npy
# Saved interictal window 2223 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2223.npy
# Saved interictal window 2224 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2224.npy
# Saved interictal window 2225 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2225.npy
# Saved interictal window 2226 to D:/chb-mit-scalp-eeg-database-1.0.0/interictal_windows\interictal_window_2226.npy
